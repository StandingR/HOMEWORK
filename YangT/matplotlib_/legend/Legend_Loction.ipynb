# %%
"""
Legend Locations
upper left upper center upper right

center left    center   center right

lower right     lower center  lower right


"""

# %% [markdown]
# ## Legend Locations

# %%
import matplotlib.pyplot as plt
import numpy as np

n_data = 100
random_noise1 = np.random.normal(0, 1, (n_data,))
random_noise2 = np.random.normal(1, 1, (n_data,))
random_noise3 = np.random.normal(2, 1, (n_data))

fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(random_noise1,
        label='random noise1')
ax.plot(random_noise2,
        label='random noise2')
ax.plot(random_noise3,
        label='random noise3')

ax.tick_params(labelsize=20)

ax.legend(fontsize=20,
          loc='upper right')

# %% [markdown]
# ## ncol_Argument

# %%
import matplotlib.pyplot as plt
import numpy as np

# PI로 x값 만들기
PI = np.pi
# 왜 이걸까 궁금
t = np.linspace(-4*PI, 4*PI, 300)
sin = np.sin(t)

fig, ax = plt.subplots(figsize=(10,10))

# ax의 인덱스는 범위 12까지 출력
for ax_idx in range(12):
    label_template = 'added by {}'
    ax.plot(t, sin+ax_idx,
            label=label_template.format(ax_idx))

ax.legend(fontsize=15)

# %%
"""
loc = 'upper left'   loc = 'upper center' loc = 'upper right'

loc = 'center left'   loc = 'center right'

loc = 'lower left'    loc = 'lower center'  loc = 'lower right' 


"""

# %% [markdown]
# ## bbox_to_anchor Argument

# %%
import matplotlib.pyplot as plt
import numpy as np

n_data = 100
random_noise1 = np.random.normal(0, 1, (n_data,))
random_noise2 = np.random.normal(1, 1, (n_data,))
random_noise3 = np.random.normal(2, 1, (n_data,))

fig, ax = plt.subplots(figsize=(10, 7))
ax.tick_params(labelsize=20)

ax.plot(random_noise1,
        label = 'random noise1')
ax.plot(random_noise2,
        label = 'random noise2')
ax.plot(random_noise3,
        label = 'random noise3')

ax.legend(fontsize=20,
          bbox_to_anchor=(1,0.5),
          loc='center left')
fig.tight_layout()

# %%
"""

ax.legend(fontsize=20,
bbox_to_anchor=(-0.1,0.5),
loc = 'center right'

ax.legend(fontsize=20,
bbox_to_anchor=(0.5,1),
loc = 'lower center')

ax.legend(fontsize=20,
bbox_to_anchor=(1, 0.5)
loc = 'center left')

ax.legend(fontsize=20,
bbox_to_anchor=(0.5,-0.1),
loc = 'upper center')




"""
# Out:
# "\n\nax.legend(fontsize=20,\nbbox_to_anchor=(-0.1,0.5),\nloc = 'center right'\n\nax.legend(fontsize=20,\nbbox_to_anchor=(0.5,1),\nloc = 'lower center')\n\nax.legend(fontsize=20,\nbbox_to_anchor=(1, 0.5)\nloc = 'center left')\n\nax.legend(fontsize=20,\nbbox_to_anchor=(0.5,-0.1),\nloc = 'upper center')\n\n\n\n\n"

# %% [markdown]
# ## bbox_to_anchor_Argument

# %%
import matplotlib.pyplot as plt
import numpy as np

PI = np.pi
t = np.linspace(-4*PI, 4*PI, 300)
sin = np.sin(t)

fig, ax = plt.subplots(figsize=(10,10))

for ax_idx in range(12):
    label_template = 'added by{}'
    ax.plot(t, sin+ax_idx,
            label = label_template.format(ax_idx))
    
ax.lengend(fontsize=15,
           ncol = 4,
           bbox_to_anchor=(0.5, -0.05),
           loc = 'upper center')
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 15
#      11     label_template = 'added by{}'
#      12     ax.plot(t, sin+ax_idx,
#      13             label = label_template.format(ax_idx))
# ---> 15 ax.lengend(fontsize=15,
#      16            ncol = 4,
#      17            bbox_to_anchor=(0.5, -0.05),
#      18            loc = 'upper center')
#      19 fig.tight_layout()
#
# AttributeError: 'Axes' object has no attribute 'lengend'

# %% [markdown]
# ## Line Styles/ Markers with Legend

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(t, sin,
        label='sin(t)')
ax.plot(t, sin+1,
        marker='o',
        label='sin(t)+1',
        linestyle=':')

ax.plot(t, sin+2,
        marker='D',
        label='sin(t)+3',
        linestyle='-.')
ax.legend(loc='center left',
          bbox_to_anchor=(1, 0.5),
          fontsize=20)
fig.tight_layout()
